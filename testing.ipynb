# %%
import os

def get_folder_structure(root_folder):
    for folder_name, subfolders, filenames in os.walk(root_folder):
        print(f'Folder: {folder_name}')
        
        for subfolder in subfolders:
            print(f'\tSubfolder: {subfolder}')
        
        for filename in filenames:
            print(f'\tFile: {filename}')

# Call the function with your current working directory
get_folder_structure(os.getcwd())
# Out:
# Folder: c:\Users\ronit\OneDrive\Desktop\College\Sem_7\NNDL\NNDL_Repo\DL_MiniProject
# 	Subfolder: .git
# 	Subfolder: datasets
# 	Subfolder: notebooks
# 	Subfolder: pages
# 	File: count_vectorizer.pkl
# 	File: language_detection_model.pkl
# 	File: README.md
# 	File: saved_model.pb
# 	File: streamlit_app.py
# 	File: streamlit_main.py
# 	File: testing.ipynb
# Folder: c:\Users\ronit\OneDrive\Desktop\College\Sem_7\NNDL\NNDL_Repo\DL_MiniProject\.git
# 	Subfolder: hooks
# 	Subfolder: info
# 	Subfolder: logs
# 	Subfolder: objects
# 	Subfolder: refs
# 	File: COMMIT_EDITMSG
# 	File: config
# 	File: description
# 	File: FETCH_HEAD
# 	File: HEAD
# 	File: index
# 	File: ORIG_HEAD
# 	File: packed-refs
# Folder: c:\Users\ronit\OneDrive\Desktop\College\Sem_7\NNDL\NNDL_Repo\DL_MiniProject\.git\hooks
# 	File: applypatch-msg.sample
# 	File: commit-msg.sample
# 	File: fsmonitor-watchman.sample
# 	File: post-update.sample
# 	File: pre-applypatch.sample
# 	File: pre-commit.sample
# ...

# %%
import pickle

# Test loading polynomial features
try:
    with open(r'C:\Users\ASUS\Desktop\College\Sem7\DL\M1_DL_Project\DL_MiniProject\notebooks\polynomial_features.pkl', 'rb') as pf_file:
        poly_features = pickle.load(pf_file)
    print("Polynomial features loaded successfully!")
except Exception as e:
    print(f"Error loading polynomial features: {e}")

# Test loading RandomForest model
try:
    with open(r'C:\Users\ASUS\Desktop\College\Sem7\DL\M1_DL_Project\DL_MiniProject\notebooks\random_forest_model.pkl', 'rb') as rf_file:
        model = pickle.load(rf_file)
    print("Random forest model loaded successfully!")
except Exception as e:
    print(f"Error loading random forest model: {e}")

# Test loading scaler
try:
    with open(r'C:\Users\ASUS\Desktop\College\Sem7\DL\M1_DL_Project\DL_MiniProject\notebooks\scaler.pkl', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)
    print("Scaler loaded successfully!")
except Exception as e:
    print(f"Error loading scaler: {e}")

# Test loading linear regression model
try:
    with open(r'C:\Users\ASUS\Desktop\College\Sem7\DL\M1_DL_Project\DL_MiniProject\notebooks\linear_regression_poly_model.pkl', 'rb') as lr_file:
        lr_model = pickle.load(lr_file)
    print("Linear regression model loaded successfully!")
except Exception as e:
    print(f"Error loading linear regression model: {e}")
# Out:
# Polynomial features loaded successfully!
# Error loading random forest model: invalid load key, '\x01'.
# Scaler loaded successfully!
# Error loading linear regression model: invalid load key, '\x0f'.

# %%
import pickle

# Test loading polynomial features
try:
    with open(r'C:\Users\ronit\OneDrive\Desktop\College\Sem_7\NNDL\NNDL_Repo\DL_MiniProject\random_forest_model.pkl', 'rb') as rf_file:
        model = pickle.load(rf_file)
    print("Random forest model loaded successfully!")
except Exception as e:
    print(f"Error loading random forest model: {e}")
# Out:
# Error loading random forest model: invalid load key, '\x02'.

# %%
import joblib

# Test loading the RandomForestRegressor model using joblib
try:
    model = joblib.load(r'C:\Users\ronit\OneDrive\Desktop\College\Sem_7\NNDL\NNDL_Repo\DL_MiniProject\random_forest_model.pkl')
    print("Random forest model loaded successfully!")
except Exception as e:
    print(f"Error loading random forest model: {e}")
# Out:
# Random forest model loaded successfully!
